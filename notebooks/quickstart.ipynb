# %% [markdown]
# # markovmodus quickstart
#
# This notebook shows the main `markovmodus` workflow at the example of one small branching system: `0 -> 1 -> 3` and `0 -> 2 -> 3`, with equal transition rates on all allowed edges.

# %% [markdown]
# ## Preparations

# %% [markdown]
# Install the package with `pip install markovmodus`. If you are running inside the repository, you can use the uv-managed environment to install all dependencies.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc

from markovmodus import SimulationParameters, simulate_dataset

# %%
# Helper functions.
def num_states_from_adata(adata) -> int:
    return int(np.asarray(adata.uns["state_expression"]).shape[0])


def state_palette(num_states: int) -> list:
    cmap = plt.get_cmap("tab10")
    return [cmap(state % cmap.N) for state in range(num_states)]


def plot_transition_graph(
    matrix: np.ndarray,
    title: str,
    *,
    ax: plt.Axes,
    positions: np.ndarray | None = None,
    palette: list | None = None,
) -> None:
    matrix = np.asarray(matrix, dtype=float)
    num_states = matrix.shape[0]
    if positions is None:
        angles = np.linspace(0, 2 * np.pi, num_states, endpoint=False)
        positions = np.stack((np.cos(angles), np.sin(angles)), axis=1)
    else:
        positions = np.asarray(positions, dtype=float)

    max_rate = float(matrix.max())
    ax.set_title(title, fontsize=13, pad=10)
    ax.set_aspect("equal")
    margin = 0.45
    ax.set_xlim(float(positions[:, 0].min() - margin), float(positions[:, 0].max() + margin))
    ax.set_ylim(float(positions[:, 1].min() - margin), float(positions[:, 1].max() + margin))
    ax.axis("off")

    node_radius = 0.12
    if palette is None:
        palette = state_palette(num_states)
    edge_color = "0.58"

    if max_rate > 0:
        for source in range(num_states):
            for target in range(num_states):
                rate = matrix[source, target]
                if source == target or rate <= 0:
                    continue

                source_pos = positions[source]
                target_pos = positions[target]
                bidirectional = matrix[target, source] > 0
                rad = 0.20 if bidirectional else 0.03
                linewidth = 1.4 + 1.8 * (rate / max_rate)

                ax.annotate(
                    "",
                    xy=target_pos,
                    xytext=source_pos,
                    arrowprops=dict(
                        arrowstyle="-|>",
                        color=edge_color,
                        alpha=0.85,
                        lw=linewidth,
                        mutation_scale=14,
                        shrinkA=18,
                        shrinkB=18,
                        connectionstyle=f"arc3,rad={rad}",
                    ),
                    zorder=1,
                )

                direction = target_pos - source_pos
                normal = np.array([-direction[1], direction[0]])
                norm = np.linalg.norm(normal)
                if norm > 0:
                    normal = normal / norm
                label_position = 0.55 * source_pos + 0.45 * target_pos + normal * rad * 0.55
                ax.text(
                    label_position[0],
                    label_position[1],
                    f"{rate:.2f}",
                    fontsize=8,
                    color="0.35",
                    ha="center",
                    va="center",
                    bbox=dict(facecolor="white", edgecolor="none", alpha=0.75, pad=0.8),
                    zorder=2,
                )

    for state, (x, y) in enumerate(positions):
        node = plt.Circle(
            (x, y),
            node_radius,
            facecolor=palette[state % len(palette)],
            edgecolor="black",
            linewidth=1.2,
            zorder=3,
        )
        ax.add_patch(node)
        ax.text(
            x,
            y,
            str(state),
            ha="center",
            va="center",
            color="white",
            fontsize=12,
            weight="bold",
            zorder=4,
        )


def preprocess_for_scanpy(adata):
    adata.obs["state"] = adata.obs["state"].astype("category")
    sc.pp.normalize_total(adata)
    sc.pp.log1p(adata)
    adata.layers["log_normalized"] = adata.X.copy()

    analysis = adata.copy()
    sc.pp.scale(analysis, max_value=10)
    sc.tl.pca(analysis, n_comps=20)
    sc.pp.neighbors(analysis, n_neighbors=15)
    sc.tl.umap(analysis)
    adata.obsm["X_pca"] = analysis.obsm["X_pca"].copy()
    adata.obsm["X_umap"] = analysis.obsm["X_umap"].copy()
    return adata


def state_counts(adata) -> pd.Series:
    counts = adata.obs["state"].astype(int).value_counts().reindex(
        range(num_states_from_adata(adata)), fill_value=0
    )
    counts.index.name = "state"
    return counts


def plot_state_counts(
    adata,
    title: str,
    *,
    ax: plt.Axes,
    palette: list | None = None,
) -> None:
    counts = state_counts(adata)
    if palette is None:
        palette = state_palette(num_states_from_adata(adata))
    bar_colors = [palette[int(state) % len(palette)] for state in counts.index]
    counts.plot(kind="bar", ax=ax, color=bar_colors)
    ax.set_xlabel("State index")
    ax.set_ylabel("Cells")
    ax.set_title(title)


def total_count_size_factors(adata, *, target_sum: float = 1e4) -> np.ndarray:
    totals = np.asarray(adata.layers["spliced"].sum(axis=1)).ravel().astype(float)
    return np.divide(target_sum, totals, out=np.zeros_like(totals), where=totals > 0)


def plot_us_counts(
    adata,
    gene: str,
    title: str,
    *,
    ax: plt.Axes,
    palette: list | None = None,
    log_normalize: bool = False,
) -> None:
    gene_idx = int(np.where(adata.var_names == gene)[0][0])
    unspliced = np.asarray(adata.layers["unspliced"][:, gene_idx]).ravel()
    spliced = np.asarray(adata.layers["spliced"][:, gene_idx]).ravel()
    if log_normalize:
        size_factors = total_count_size_factors(adata)
        unspliced = np.log1p(unspliced * size_factors)
        spliced = np.log1p(spliced * size_factors)
    states = adata.obs["state"].astype(int).to_numpy()
    if palette is None:
        palette = state_palette(num_states_from_adata(adata))

    for state in sorted(np.unique(states)):
        mask = states == state
        ax.scatter(
            unspliced[mask],
            spliced[mask],
            s=18,
            alpha=0.7,
            label=f"state {state}",
            color=palette[int(state) % len(palette)],
        )
    prefix = "log-normalized " if log_normalize else "raw "
    ax.set_xlabel(f"{prefix}unspliced {gene}")
    ax.set_ylabel(f"{prefix}spliced {gene}")
    ax.set_title(title)
    ax.legend()


def plot_gene_expression(
    adata,
    gene: str,
    title: str,
    *,
    ax: plt.Axes,
    layer: str | None = "log_normalized",
    palette: list | None = None,
    ylabel: str | None = None,
) -> None:
    gene_idx = int(np.where(adata.var_names == gene)[0][0])
    if layer is None:
        expression = np.asarray(adata.X[:, gene_idx]).ravel()
    else:
        expression = np.asarray(adata.layers[layer][:, gene_idx]).ravel()
    states = adata.obs["state"].astype(int).to_numpy()
    rng = np.random.default_rng(0)
    num_states = num_states_from_adata(adata)
    if palette is None:
        palette = state_palette(num_states)

    values_by_state = [expression[states == state] for state in range(num_states)]
    box = ax.boxplot(
        values_by_state,
        positions=np.arange(num_states),
        widths=0.45,
        patch_artist=True,
        showfliers=False,
        medianprops={"color": "black", "linewidth": 1.2},
    )
    for state, patch in enumerate(box["boxes"]):
        patch.set_facecolor(palette[state % len(palette)])
        patch.set_alpha(0.25)
        patch.set_edgecolor(palette[state % len(palette)])

    for state, values in enumerate(values_by_state):
        jitter = rng.normal(0.0, 0.045, size=values.size)
        ax.scatter(
            np.full(values.size, state) + jitter,
            values,
            s=16,
            alpha=0.55,
            color=palette[state % len(palette)],
        )

    ax.set_xticks(np.arange(num_states))
    ax.set_xticklabels([str(state) for state in range(num_states)])
    ax.set_xlabel("State index")
    if ylabel is None:
        ylabel = f"expression of {gene}"
    ax.set_ylabel(ylabel)
    ax.set_title(title)


def _gene_indices(var_names, genes: list[str]) -> list[int]:
    return [int(np.where(var_names == gene)[0][0]) for gene in genes]


def observed_expression_by_state(
    adata,
    genes: list[str],
) -> np.ndarray:
    gene_indices = _gene_indices(adata.var_names, genes)
    expression = np.asarray(adata.layers["spliced"][:, gene_indices])
    states = adata.obs["state"].astype(int).to_numpy()
    rows = []
    for state_index in range(num_states_from_adata(adata)):
        mask = states == state_index
        if mask.any():
            rows.append(expression[mask].mean(axis=0))
        else:
            rows.append(np.full(len(genes), np.nan))
    return np.vstack(rows)


def plot_configured_and_observed_expression(
    adata,
    genes: list[str],
    *,
    axes: tuple[plt.Axes, plt.Axes],
) -> None:
    configured_indices = _gene_indices(adata.var_names, genes)
    configured = np.asarray(adata.uns["state_expression"], dtype=float)[:, configured_indices]
    observed = observed_expression_by_state(adata, genes)
    state_indices = np.arange(num_states_from_adata(adata))
    label_step = max(1, len(genes) // 16)
    tick_positions = np.arange(0, len(genes), label_step)

    panels = [
        (axes[0], configured, "Configured expression", "steady-state target"),
        (axes[1], observed, "Observed expression", "mean raw spliced count"),
    ]
    for ax, matrix, title, colorbar_label in panels:
        im = ax.imshow(matrix, aspect="auto", interpolation="nearest", cmap="viridis")
        ax.set_title(title)
        ax.set_yticks(state_indices)
        ax.set_yticklabels([str(state) for state in state_indices])
        ax.set_ylabel("State index")
        ax.set_xticks(tick_positions)
        ax.set_xticklabels([genes[index] for index in tick_positions], rotation=90, fontsize=7)
        ax.set_xlabel("genes")
        ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04, label=colorbar_label)


def plot_embedding_with_state_labels(
    adata,
    coordinates: np.ndarray,
    title: str,
    *,
    ax: plt.Axes,
    palette: list,
    xlabel: str,
    ylabel: str,
) -> None:
    states = adata.obs["state"].astype(int).to_numpy()
    for state in range(num_states_from_adata(adata)):
        mask = states == state
        if not mask.any():
            continue
        color = palette[state % len(palette)]
        ax.scatter(
            coordinates[mask, 0],
            coordinates[mask, 1],
            s=18,
            alpha=1.0,
            color=color,
            linewidths=0,
            zorder=1,
        )
        center = coordinates[mask].mean(axis=0)
        ax.scatter(
            center[0],
            center[1],
            s=500,
            color=color,
            edgecolor="black",
            linewidth=1.2,
            alpha=1,
            zorder=3,
        )
        ax.text(
            center[0],
            center[1],
            str(state),
            ha="center",
            va="center",
            color="white",
            fontsize=12,
            weight="bold",
            alpha=1,
            zorder=4,
        )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)


def plot_scanpy_views(
    adata,
    title: str,
    *,
    axes: tuple[plt.Axes, plt.Axes],
    palette: list | None = None,
) -> None:
    if palette is None:
        palette = state_palette(num_states_from_adata(adata))
    pca_ax, umap_ax = axes
    plot_embedding_with_state_labels(
        adata,
        adata.obsm["X_pca"][:, :2],
        f"{title}: PCA",
        ax=pca_ax,
        palette=palette,
        xlabel="PC1",
        ylabel="PC2",
    )
    plot_embedding_with_state_labels(
        adata,
        adata.obsm["X_umap"],
        f"{title}: UMAP",
        ax=umap_ax,
        palette=palette,
        xlabel="UMAP1",
        ylabel="UMAP2",
    )

# %% [markdown]
# ## Define a transition model and set simulation parameters
#
# A simulation is configured by an instance of the `SimulationParameters` class.
#
# The key input for the latent dynamics is `transition_rates`, an `n x n` matrix where rows are source states and columns are destination states. Off-diagonal entries are continuous-time rates; diagonal entries are ignored and set internally.
# In the current example, all cells start in state 0. They can branch to state 1 or state 2, and both branches can then move to state 3. Increasing `transition_rate` or `t_final` would push more cells toward state 3. Decreasing them would leave more cells in state 0 or in the intermediate states.
#
# The key input for the gene expression dynamics of individual cells is the state-by-gene spliced-count target matrix. Here we use the shorthand options: with `markers_per_state=20`, each latent state gets 20 genes with elevated target expression, and with `marker_overlap=5`, every pair of states connected by a non-zero transition rate shares five marker genes. The shorthand is materialized as `params.state_expression` and stored in the AnnData output.

# %%
# Define the transition rates.
transition_rates = np.array(
    [
        [0.0, 0.05, 0.05, 0.0],
        [0.0, 0.0, 0.0, 0.05],
        [0.0, 0.0, 0.0, 0.05],
        [0.0, 0.0, 0.0, 0.0],
    ]
)

# Set the parameters for simulating a dataset with the specified transition graph.
params = SimulationParameters(
    # Latent dynamics.
    num_states=4,
    transition_rates=transition_rates,

    # State-specific spliced-count targets and U/S dynamics.
    num_genes=70,
    markers_per_state=20,
    marker_overlap=5,
    baseline_expression=0.25,
    marker_expression=15.0,
    splicing_rate=.5,
    decay_rate=.5,

    # Initial condition.
    initial_state_probs=[1.0, 0.0, 0.0, 0.0],

    # Simulation size, time, and reproducibility.
    num_cells=400,
    t_final=15.0,
    dt=1.0,
    rng_seed=11,
)

state_colors = state_palette(params.num_states)


# Plot the configured transition graph.
fig, ax = plt.subplots(figsize=(5.5, 3.6))
state_positions = np.array(
    [
        [-1.0, 0.0],
        [0.0, 0.65],
        [0.0, -0.65],
        [1.0, 0.0],
    ]
)

plot_transition_graph(
    transition_rates,
    "Branching transition graph",
    ax=ax,
    positions=state_positions,
    palette=state_colors,
)
plt.tight_layout()

# %% [markdown]
# ## Simulate an AnnData dataset
#
# `simulate_dataset(params)` returns an AnnData object. `X` is populated with the raw spliced counts, `layers["unspliced"]` and `layers["spliced"]` contain the two RNA count matrices, and `obs["state"]` records the latent state index for each cell. The transition matrix, state-expression targets, and other simulation metadata are saved to `uns`.

# %%
adata = simulate_dataset(params)
adata

# %% [markdown]
# **DataFrame output**
#
# AnnData is the default because it fits Scanpy and related single-cell workflows.
# If a tabular representation is more convenient, request `output="dataframe"` to get a pandas dataframe with one row per cell and metadata plus wide U/S count columns, or `output="both"` to get both the AnnData and the DataFrame.

# %%
# df = simulate_dataset(params, output="dataframe")
# adata, df = simulate_dataset(params, output="both")
# df.head()

# %% [markdown]
# ## Inspecting the data

# %% [markdown]
# We begin with standard Scanpy preprocessing: total-count normalization, log transformation, PCA, nearest-neighbor graph construction, and UMAP. This mutates `adata.X` in place, while raw U/S counts remain available in `adata.layers["unspliced"]` and `adata.layers["spliced"]`.

# %%
adata = preprocess_for_scanpy(adata)
adata

# %% [markdown]
# The following plots show how the transition rates and final simulation time shaped the final population.
#
# In this branch model, states 1 and 2 should be roughly balanced because their rates are equal, while state 3 should accumulate cells that have moved through either branch.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
plot_scanpy_views(adata, "Branching model", axes=axes[0:2], palette=state_colors)
plot_state_counts(adata, "State occupancy", ax=axes[2], palette=state_colors)
plt.tight_layout()

# %% [markdown]
# #### Configured and observed expression programs
#
# The heatmap on the left is the full state-by-gene spliced-count target program used by the simulator. The heatmap on the right shows the corresponding mean raw spliced counts observed in each final state.
#
# These two panels are not expected to match perfectly.
# Cells can transition shortly before the final time, molecule counts are stochastic, and state 3 collects cells from both branches.

# %%
heatmap_genes = list(adata.var_names)

fig, axes = plt.subplots(1, 2, figsize=(14, 4.5))
plot_configured_and_observed_expression(
    adata,
    heatmap_genes,
    axes=axes,
)
plt.tight_layout()

# %% [markdown]
# ### U/S plots for an example gene
#
# Here we use `gene_35`, which is specific to the second latent state, state index 1, under the systematic marker-gene allocation used by this parameter configuration.
#
# The U/S panel uses raw unspliced and spliced molecule counts, while the expression panel shows the same gene after total-count normalization and log transformation.

# %%
marker_state = 1
marker_gene = "gene_35"

fig, axes = plt.subplots(2, 2, figsize=(12, 9))
plot_gene_expression(
    adata,
    marker_gene,
    f"Raw spliced counts for {marker_gene}",
    ax=axes[0, 0],
    layer="spliced",
    palette=state_colors,
    ylabel=f"raw spliced counts of {marker_gene}",
)
plot_us_counts(
    adata,
    marker_gene,
    f"Raw U/S counts for state-{marker_state} marker {marker_gene}",
    ax=axes[0, 1],
    palette=state_colors,
)
plot_gene_expression(
    adata,
    marker_gene,
    f"Log-normalized expression for {marker_gene}",
    ax=axes[1, 0],
    layer="log_normalized",
    palette=state_colors,
    ylabel=f"log-normalized expression of {marker_gene}",
)
plot_us_counts(
    adata,
    marker_gene,
    f"Log-normalized U/S counts for {marker_gene}",
    ax=axes[1, 1],
    palette=state_colors,
    log_normalize=True,
)
plt.tight_layout()

# %% [markdown]
# ## Next steps
#
# This quickstart uses a static transition matrix and no proliferation. More examples are available in:
#
# - `dynamic_transition_rates_example.ipynb` for an example with time- and population-dependent transition-rate callbacks.
# - `proliferation_example.ipynb` for an example with density-limited division.
# - `qad_example.ipynb` for a larger QAD-like differentiation example with M2-restricted division and D-dependent feedback.
